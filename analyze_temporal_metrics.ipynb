# %%
import pandas as pd

# %%
def group_by_param(df, params):
    all_cols = ['Case', 'Model Dir', 'Model Class', 'From End Threshold', 'VAD Threshold']
    no_param_cols = [col for col in all_cols if col not in params]
    df_copy = df.copy()
    df_copy = df_copy.drop(columns=no_param_cols)
    grouped_stats = df_copy.groupby(params).agg(['mean', 'std'])
    
    # Round to 3 decimal places
    grouped_stats = grouped_stats.round(3)
    
    return grouped_stats

# %% [markdown]
# # Unseen Case

# %%
metrics_dir = 'results/rolling_fragments/metrics'

binary_dfs = {}
weighted_dfs = {}
for model_type in ['text', 'audio', 'multimodal']:
    binary_dfs[model_type] = pd.read_csv(f'{metrics_dir}/{model_type}.csv')
    weighted_dfs[model_type] = pd.read_csv(f'{metrics_dir}/{model_type}_F1_weighted.csv')
    
binary_df = pd.concat(binary_dfs.values(), names=['model_type'])
weighted_df = pd.concat(weighted_dfs.values(), names=['model_type'])

binary_vad = pd.read_csv(f'{metrics_dir}/vad.csv')
# weighted_vad = pd.read_csv(f'{metrics_dir}/vad_F1_weighted.csv')
weighted_vad = binary_vad.copy()

# %%
# best = df.copy()
# best = best[best['Model Class'] == 'TextModel']
# best = best[best['VAD Threshold'] == 0.3]
# best = best[best['From End Threshold'] == 3]

# # Get mean and std for each metric
# best = best.agg({'Accuracy':['mean', 'std'], 'Precision': ['mean', 'std'], 'Recall': ['mean', 'std'], 'F1': ['mean', 'std'], 'ROC AUC': ['mean', 'std'],})
# best = best.round(3)
# best

# %%
binary_df_ = binary_df[binary_df['VAD Threshold'] == 0.3]
binary_df_ = binary_df_[binary_df_['From End Threshold'] == 0]

weighted_df_ = weighted_df[weighted_df['VAD Threshold'] == 0.3]
weighted_df_ = weighted_df_[weighted_df_['From End Threshold'] == 0]

binary_df_ = group_by_param(binary_df, ['Model Class'])
weighted_df_ = group_by_param(weighted_df, ['Model Class'])

print("Binary:")
display(binary_df_)
print("Weighted:")
display(weighted_df_)
# Out:
# Binary:
#                      Accuracy        Precision        Recall            F1  \
#                          mean    std      mean    std   mean    std   mean
# Model Class
# AudioModel              0.633  0.105     0.334  0.174  0.606  0.096  0.403
# AudioTextFusionModel    0.657  0.093     0.360  0.178  0.700  0.061  0.451
# TextModel               0.739  0.040     0.417  0.168  0.693  0.092  0.501
#
#                             ROC AUC
#                         std    mean    std
# Model Class
# AudioModel            0.135   0.625  0.055
# AudioTextFusionModel  0.159   0.671  0.057
# TextModel             0.140   0.718  0.038
# Weighted:
#                      Accuracy        Precision        Recall            F1  \
#                          mean    std      mean    std   mean    std   mean
# Model Class
# AudioModel              0.633  0.105     0.761  0.093  0.633  0.105  0.667
# AudioTextFusionModel    0.657  0.093     0.789  0.079  0.657  0.093  0.692
# TextModel               0.739  0.040     0.812  0.065  0.739  0.040  0.762
#
#                             ROC AUC
#                         std    mean    std
# Model Class
# AudioModel            0.099   0.625  0.055
# AudioTextFusionModel  0.079   0.671  0.057
# TextModel             0.045   0.718  0.038

# %%
binary_vad_ = binary_vad[binary_vad['VAD Threshold'] == 0]
binary_vad_ = binary_vad_[binary_vad_['From End Threshold'] == 0]

weighted_vad_ = weighted_vad[weighted_vad['VAD Threshold'] == 0]
weighted_vad_ = weighted_vad_[weighted_vad_['From End Threshold'] == 0]

binary_vad_ = group_by_param(binary_vad_, ['Model Class'])
weighted_vad_ = group_by_param(weighted_vad_, ['Model Class'])

print("Binary:")
display(binary_vad_)
print("Weighted:")
display(weighted_vad_)
# Out:
# Binary:
#             Accuracy        Precision        Recall          F1         \
#                 mean    std      mean    std   mean  std   mean    std
# Model Class
# VAD            0.284  0.168     0.284  0.168    1.0  0.0  0.421  0.197
#
#             ROC AUC
#                mean  std
# Model Class
# VAD             0.5  0.0
# Weighted:
#             Accuracy        Precision        Recall          F1         \
#                 mean    std      mean    std   mean  std   mean    std
# Model Class
# VAD            0.284  0.168     0.284  0.168    1.0  0.0  0.421  0.197
#
#             ROC AUC
#                mean  std
# Model Class
# VAD             0.5  0.0

# %% [markdown]
# # Unseen Surgeon

# %%
df = pd.read_csv('results/rolling_fragments/metrics/unseen_surgeon.csv')
df.head()
# Out:
#    Case Model Class                                          Model Dir  \
# 0     1   TextModel  results/checkpoints/text/Whiper-BERT remove=1,...
# 1     1   TextModel  results/checkpoints/text/Whiper-BERT remove=1,...
# 2     2   TextModel  results/checkpoints/text/Whiper-BERT remove=1,...
# 3     2   TextModel  results/checkpoints/text/Whiper-BERT remove=1,...
# 4     6   TextModel  results/checkpoints/text/Whiper-BERT remove=1,...
#
#    VAD Threshold  From End Threshold Metrics Weighting  Accuracy  Precision  \
# 0            0.3                   3            binary  0.742639   0.657258
# 1            0.3                   3          weighted  0.742639   0.763731
# 2            0.3                   3            binary  0.727023   0.521739
# 3            0.3                   3          weighted  0.727023   0.768558
# 4            0.3                   3            binary  0.678952   0.191686
#
#      Recall        F1   ROC AUC
# 0  0.831633  0.734234  0.753912
# 1  0.742639  0.743563  0.753912
# 2  0.735849  0.610568  0.729627
# 3  0.727023  0.737722  0.729627
# 4  0.664000  0.297491  0.672328

# %%
df['Model Class'].unique()
# Out:
# array(['TextModel', 'AudioModel', 'VAD', 'AudioTextFusionModel'],
#       dtype=object)

# %%
group_by_param(df, ['Model Class', 'Metrics Weighting'])
# Out:
#                                        Accuracy        Precision         \
#                                            mean    std      mean    std
# Model Class          Metrics Weighting
# AudioModel           binary               0.734  0.110     0.252  0.139
#                      weighted             0.734  0.110     0.779  0.111
# AudioTextFusionModel binary               0.575  0.088     0.277  0.142
#                      weighted             0.575  0.088     0.761  0.108
# TextModel            binary               0.795  0.086     0.369  0.150
#                      weighted             0.795  0.086     0.835  0.072
# VAD                  binary               0.188  0.113     0.188  0.113
#                      weighted             0.188  0.113     0.048  0.052
#
#                                        Recall            F1        ROC AUC  \
#                                          mean    std   mean    std    mean
# Model Class          Metrics Weighting
# AudioModel           binary             0.335  0.173  0.261  0.109   0.570
#                      weighted           0.734  0.110  0.746  0.111   0.570
# AudioTextFusionModel binary             0.678  0.128  0.379  0.168   0.599
#                      weighted           0.575  0.088  0.615  0.100   0.599
# TextModel            binary             0.534  0.192  0.423  0.155   0.680
#                      weighted           0.795  0.086  0.807  0.081   0.680
# VAD                  binary             1.000  0.000  0.302  0.155   0.500
#                      weighted           0.188  0.113  0.074  0.074   0.500
#
#
#                                           std
# Model Class          Metrics Weighting
# AudioModel           binary             0.053
#                      weighted           0.053
# AudioTextFusionModel binary             0.062
#                      weighted           0.062
# TextModel            binary             0.066
#                      weighted           0.066
# VAD                  binary             0.000
#                      weighted           0.000
